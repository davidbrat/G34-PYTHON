# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
# !pip install numpy
# !pip install pandas
# !pip install datatime
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement datatime (from versions: none)
# ERROR: No matching distribution found for datatime
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/104.6 kB 660.6 kB/s eta 0:00:01
#      ---------------------------- -------- 81.9/104.6 kB 762.6 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.6 kB 737.3 kB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('company_sales_data.csv')
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

# Plot total profit per month
plt.plot(df['month_number'], df['total_profit'], marker='o', color='green')
plt.title('Company Profit per Month')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.grid(True)
plt.show()

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
# Plot sales data of each product
products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
for product in products:
    plt.plot(df['month_number'], df[product], marker='o', label=product)
plt.title('Sales Data of Products per Month')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %% [markdown]
# ### Expected Output:
# ![image.png](attachment:image.png)

# %%
# Bar chart for bathing soap sales
plt.bar(df['month_number'], df['bathingsoap'], color='skyblue')
plt.title('Bathing Soap Sales per Month')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.grid(True)
plt.show()
